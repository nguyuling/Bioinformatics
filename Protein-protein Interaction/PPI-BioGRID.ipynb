# %% [markdown]
# ## Getting Protein-Protein Interaction Data from BioGRID DB

# %% [markdown]
# ### 0. Required libraries
# This example focuses on accessing the protein-protein interaction data from BioGRID DB via provided REST API from the database. In this case, few libraries are used:
# 1. `requests` used for performing the web request and retrieval of response.
# 2. `pandas` used for transforming the retrieved response (in JSON) to data frame.
# 3. `networkx` used for constructing the network graph structure from the protein-protein information.
# 4. `matplotlib` to support for the drawing functions in `networkx`

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx

# %% [markdown]
# ### 0. Register to get data from BioGRID DB
# Go to https://webservice.thebiogrid.org and register and get the access key, please copy it!

# %% [markdown]
# ### 1. Accessing the Web API of BioGRID DB
# The following code shows the steps in accessing the Web API of BioGRID DB. First we need to setup the default endpoint of API to get the data, which is https://webservice.thebiogrid.org/interactions . Then, setup the parameters required such as the `accessKey`, `organism`, `geneList` and `format` as in the example. Details of the parameters available can refer to BioGRID API documentation. https://wiki.thebiogrid.org/doku.php/biogridrest<br><br>
# Then will use the API endpoint url and the parameters to request response from the webserver. The returned response will be parsed using the `json()` function. <br><br>
# <span style='color:red'>Note: Please always check if the response having the correct outcome or any error messages

# %%
biogrid_url = "https://webservice.thebiogrid.org/interactions"
params = {
    "accessKey":"585b23750ef5fd7f8c3b0a3170e41e3d",
    "format":"json",
    "searchNames": True,
    "geneList":"MB",
    "organism":9606,
    "searchbiogridids":True,
    "includeInteractors":True
}
response = requests.get(biogrid_url, params=params)
network  = response.json()

# %%
network
# Out:
# {'504736': {'BIOGRID_INTERACTION_ID': 504736,
#   'ENTREZ_GENE_A': '5710',
#   'ENTREZ_GENE_B': '4151',
#   'BIOGRID_ID_A': 111683,
#   'BIOGRID_ID_B': 110321,
#   'SYSTEMATIC_NAME_A': 'RP11-126K1.1',
#   'SYSTEMATIC_NAME_B': 'RP4-569D19.7',
#   'OFFICIAL_SYMBOL_A': 'PSMD4',
#   'OFFICIAL_SYMBOL_B': 'MB',
#   'SYNONYMS_A': 'AF|AF-1|ASF|MCB1|Rpn10|S5A|pUB-R5',
#   'SYNONYMS_B': 'PVALB|myoglobgin',
#   'EXPERIMENTAL_SYSTEM': 'Affinity Capture-MS',
#   'EXPERIMENTAL_SYSTEM_TYPE': 'physical',
#   'PUBMED_AUTHOR': 'Weekes J (2003)',
#   'PUBMED_ID': 12601813,
#   'ORGANISM_A': 9606,
#   'ORGANISM_B': 9606,
#   'THROUGHPUT': 'Low Throughput',
#   'QUANTITATION': '-',
#   'MODIFICATION': '-',
#   'ONTOLOGY_TERMS': {},
#   'QUALIFICATIONS': '-',
#   'TAGS': '-',
#   'SOURCEDB': 'BIOGRID'},
#  '738356': {'BIOGRID_INTERACTION_ID': 738356,
#   'ENTREZ_GENE_A': '4151',
#   'ENTREZ_GENE_B': '351',
#   'BIOGRID_ID_A': 110321,
#   'BIOGRID_ID_B': 106848,
#   'SYSTEMATIC_NAME_A': 'RP4-569D19.7',
#   'SYSTEMATIC_NAME_B': '-',
#   'OFFICIAL_SYMBOL_A': 'MB',
#   'OFFICIAL_SYMBOL_B': 'APP',
#   'SYNONYMS_A': 'PVALB|myoglobgin',
#   'SYNONYMS_B': 'AAA|ABETA|ABPP|AD1|APPI|CTFgamma|CVAP|PN-II|PN2',
#   'EXPERIMENTAL_SYSTEM': 'Reconstituted Complex',
#   'EXPERIMENTAL_SYSTEM_TYPE': 'physical',
#   'PUBMED_AUTHOR': 'Olah J (2011)',
#   'PUBMED_ID': 21832049,
#   'ORGANISM_A': 9606,
#   'ORGANISM_B': 9606,
#   'THROUGHPUT': 'High Throughput',
#   'QUANTITATION': '-',
#   'MODIFICATION': '-',
#   'ONTOLOGY_TERMS': {},
#   'QUALIFICATIONS': '-',
#   'TAGS': '-',
#   'SOURCEDB': 'BIOGRID'},
#  '1279762': {'BIOGRID_INTERACTION_ID': 1279762,
#   'ENTREZ_GENE_A': '3316',
#   'ENTREZ_GENE_B': '4151',
#   'BIOGRID_ID_A': 109548,
#   'BIOGRID_ID_B': 110321,
#   'SYSTEMATIC_NAME_A': '-',
#   'SYSTEMATIC_NAME_B': 'RP4-569D19.7',
#   'OFFICIAL_SYMBOL_A': 'HSPB2',
#   'OFFICIAL_SYMBOL_B': 'MB',
#   'SYNONYMS_A': 'HSP27|Hs.78846|LOH11CR1K|MKBP',
#   'SYNONYMS_B': 'PVALB|myoglobgin',
#   'EXPERIMENTAL_SYSTEM': 'Two-hybrid',
#   'EXPERIMENTAL_SYSTEM_TYPE': 'physical',
#   'PUBMED_AUTHOR': 'Grose JH (2015)',
#   'PUBMED_ID': 26465331,
#   'ORGANISM_A': 9606,
#   'ORGANISM_B': 9606,
#   'THROUGHPUT': 'High Throughput',
#   'QUANTITATION': '-',
#   'MODIFICATION': '-',
#   'ONTOLOGY_TERMS': {},
#   'QUALIFICATIONS': '-',
#   'TAGS': '-',
#   'SOURCEDB': 'BIOGRID'},
#  '2237373': {'BIOGRID_INTERACTION_ID': 2237373,
#   'ENTREZ_GENE_A': '4151',
#   'ENTREZ_GENE_B': '286',
#   'BIOGRID_ID_A': 110321,
#   'BIOGRID_ID_B': 106783,
#   'SYSTEMATIC_NAME_A': 'RP4-569D19.7',
#   'SYSTEMATIC_NAME_B': '-',
#   'OFFICIAL_SYMBOL_A': 'MB',
#   'OFFICIAL_SYMBOL_B': 'ANK1',
#   'SYNONYMS_A': 'PVALB|myoglobgin',
#   'SYNONYMS_B': 'ANK|SPH1|SPH2',
#   'EXPERIMENTAL_SYSTEM': 'Affinity Capture-MS',
#   'EXPERIMENTAL_SYSTEM_TYPE': 'physical',
#   'PUBMED_AUTHOR': 'Huttlin EL (2017)',
#   'PUBMED_ID': 28514442,
#   'ORGANISM_A': 9606,
#   'ORGANISM_B': 9606,
#   'THROUGHPUT': 'High Throughput',
#   'QUANTITATION': '0.995671066',
#   'MODIFICATION': '-',
#   'ONTOLOGY_TERMS': {},
#   'QUALIFICATIONS': 'BioPlex 2.0 HEK 293T cells CompPASS score = 0.995671066, threshold = 0.75. Quantitative scores calculated by CompPASS-Plus (Huttlin et al. Cell, 2015, PMID: 26186194).|See BioPlex Interactome for details (https://bioplex.hms.harvard.edu/index.php).|This data has also been reanalyzed as part of BioPlex 3.0 (PMID: 33961781) and may be re-scored from BioPlex 1.0 (PMID: 26186194). Only scores from within BioPlex 2.0 (PMID: 28514442) should be compared directly.',
#   'TAGS': '-',
#   'SOURCEDB': 'BIOGRID'},
#  '2259172': {'BIOGRID_INTERACTION_ID': 2259172,
#   'ENTREZ_GENE_A': '1325',
#   'ENTREZ_GENE_B': '4151',
#   'BIOGRID_ID_A': 107718,
#   'BIOGRID_ID_B': 110321,
#   'SYSTEMATIC_NAME_A': 'UNQ307/PRO350',
#   'SYSTEMATIC_NAME_B': 'RP4-569D19.7',
#   'OFFICIAL_SYMBOL_A': 'CORT',
#   'OFFICIAL_SYMBOL_B': 'MB',
#   'SYNONYMS_A': 'CST-14|CST-17|CST-29',
#   'SYNONYMS_B': 'PVALB|myoglobgin',
#   'EXPERIMENTAL_SYSTEM': 'Affinity Capture-MS',
#   'EXPERIMENTAL_SYSTEM_TYPE': 'physical',
#   'PUBMED_AUTHOR': 'Huttlin EL (2017)',
#   'PUBMED_ID': 28514442,
#   'ORGANISM_A': 9606,
#   'ORGANISM_B': 9606,
#   'THROUGHPUT': 'High Throughput',
#   'QUANTITATION': '0.897240724',
#   'MODIFICATION': '-',
#   'ONTOLOGY_TERMS': {},
#   'QUALIFICATIONS': 'BioPlex 2.0 HEK 293T cells CompPASS score = 0.897240724, threshold = 0.75. Quantitative scores calculated by CompPASS-Plus (Huttlin et al. Cell, 2015, PMID: 26186194).|See BioPlex Interactome for details (https://bioplex.hms.harvard.edu/index.php).|This data has also been reanalyzed as part of BioPlex 3.0 (PMID: 33961781) and may be re-scored from BioPlex 1.0 (PMID: 26186194). Only scores from within BioPlex 2.0 (PMID: 28514442) should be compared directly.',
#   'TAGS': '-',
#   'SOURCEDB': 'BIOGRID'},
#  '2394069': {'BIOGRID_INTERACTION_ID': 2394069,
#   'ENTREZ_GENE_A': '117287',
#   'ENTREZ_GENE_B': '59108',
#   'BIOGRID_ID_A': 250731,
#   'BIOGRID_ID_B': 248730,
#   'SYSTEMATIC_NAME_A': '-',
#   'SYSTEMATIC_NAME_B': '-',
#   'OFFICIAL_SYMBOL_A': 'Park7',
#   'OFFICIAL_SYMBOL_B': 'Mb',
#   'SYNONYMS_A': 'CAP1|DJ-1|Dj1|SP22',
#   'SYNONYMS_B': '-',
#   'EXPERIMENTAL_SYSTEM': 'Affinity Capture-MS',
#   'EXPERIMENTAL_SYSTEM_TYPE': 'physical',
#   'PUBMED_AUTHOR': 'Fernandez-Caggiano M (2016)',
#   'PUBMED_ID': 26945066,
#   'ORGANISM_A': 10116,
#   'ORGANISM_B': 10116,
#   'THROUGHPUT': 'Low Throughput',
#   'QUANTITATION': '-',
#   'MODIFICATION': '-',
#   'ONTOLOGY_TERMS': {},
#   'QUALIFICATIONS': '-',
#   'TAGS': '-',
#   'SOURCEDB': 'BIOGRID'},
#  '2492369': {'BIOGRID_INTERACTION_ID': 2492369,
#   'ENTREZ_GENE_A': '1107',
#   'ENTREZ_GENE_B': '4151',
#   'BIOGRID_ID_A': 107532,
#   'BIOGRID_ID_B': 110321,
#   'SYSTEMATIC_NAME_A': '-',
#   'SYSTEMATIC_NAME_B': 'RP4-569D19.7',
#   'OFFICIAL_SYMBOL_A': 'CHD3',
#   'OFFICIAL_SYMBOL_B': 'MB',
#   'SYNONYMS_A': 'Mi-2a|Mi2-ALPHA|ZFH',
#   'SYNONYMS_B': 'PVALB|myoglobgin',
#   'EXPERIMENTAL_SYSTEM': 'Affinity Capture-MS',
#   'EXPERIMENTAL_SYSTEM_TYPE': 'physical',
#   'PUBMED_AUTHOR': 'Hoffmeister H (2017)',
#   'PUBMED_ID': 28977666,
#   'ORGANISM_A': 9606,
#   'ORGANISM_B': 9606,
#   'THROUGHPUT': 'High Throughput',
#   'QUANTITATION': '-',
#   'MODIFICATION': '-',
#   'ONTOLOGY_TERMS': {},
#   'QUALIFICATIONS': '-',
#   'TAGS': '-',
#   'SOURCEDB': 'BIOGRID'},
#  '2493156': {'BIOGRID_INTERACTION_ID': 2493156,
#   'ENTREZ_GENE_A': '1108',
#   'ENTREZ_GENE_B': '4151',
#   'BIOGRID_ID_A': 107533,
#   'BIOGRID_ID_B': 110321,
#   'SYSTEMATIC_NAME_A': '-',
#   'SYSTEMATIC_NAME_B': 'RP4-569D19.7',
#   'OFFICIAL_SYMBOL_A': 'CHD4',
#   'OFFICIAL_SYMBOL_B': 'MB',
#   'SYNONYMS_A': 'CHD-4|Mi-2b|Mi2-BETA',
#   'SYNONYMS_B': 'PVALB|myoglobgin',
#   'EXPERIMENTAL_SYSTEM': 'Affinity Capture-MS',
#   'EXPERIMENTAL_SYSTEM_TYPE': 'physical',
#   'PUBMED_AUTHOR': 'Hoffmeister H (2017)',
#   'PUBMED_ID': 28977666,
#   'ORGANISM_A': 9606,
#   'ORGANISM_B': 9606,
#   'THROUGHPUT': 'High Throughput',
#   'QUANTITATION': '-',
#   'MODIFICATION': '-',
#   'ONTOLOGY_TERMS': {},
#   'QUALIFICATIONS': '-',
#   'TAGS': '-',
#   'SOURCEDB': 'BIOGRID'},
#  '2512085': {'BIOGRID_INTERACTION_ID': 2512085,
#   'ENTREZ_GENE_A': '290364',
#   'ENTREZ_GENE_B': '59108',
#   'BIOGRID_ID_A': 253181,
#   'BIOGRID_ID_B': 248730,
#   'SYSTEMATIC_NAME_A': '-',
#   'SYSTEMATIC_NAME_B': '-',
#   'OFFICIAL_SYMBOL_A': 'Itm2b',
#   'OFFICIAL_SYMBOL_B': 'Mb',
#   'SYNONYMS_A': 'Bri|imBRI2',
#   'SYNONYMS_B': '-',
#   'EXPERIMENTAL_SYSTEM': 'Affinity Capture-MS',
#   'EXPERIMENTAL_SYSTEM_TYPE': 'physical',
#   'PUBMED_AUTHOR': 'Martins F (2018)',
#   'PUBMED_ID': 29476059,
#   'ORGANISM_A': 10116,
#   'ORGANISM_B': 10116,
#   'THROUGHPUT': 'High Throughput',
#   'QUANTITATION': '-',
#   'MODIFICATION': '-',
#   'ONTOLOGY_TERMS': {},
#   'QUALIFICATIONS': '-',
#   'TAGS': '-',
#   'SOURCEDB': 'BIOGRID'},
#  '2667790': {'BIOGRID_INTERACTION_ID': 2667790,
#   'ENTREZ_GENE_A': '17189',
#   'ENTREZ_GENE_B': '12715',
#   'BIOGRID_ID_A': 201329,
#   'BIOGRID_ID_B': 198726,
#   'SYSTEMATIC_NAME_A': '-',
#   'SYSTEMATIC_NAME_B': '-',
#   'OFFICIAL_SYMBOL_A': 'Mb',
#   'OFFICIAL_SYMBOL_B': 'Ckm',
#   'SYNONYMS_A': 'AI325109',
#   'SYNONYMS_B': 'Ckmm|M-CK|MCK',
#   'EXPERIMENTAL_SYSTEM': 'Co-fractionation',
#   'EXPERIMENTAL_SYSTEM_TYPE': 'physical',
#   'PUBMED_AUTHOR': 'Pourhaghighi R (2020)',
#   'PUBMED_ID': 32325033,
#   'ORGANISM_A': 10090,
#   'ORGANISM_B': 10090,
#   'THROUGHPUT': 'High Throughput',
#   'QUANTITATION': '0.8175',
#   'MODIFICATION': '-',
#   'ONTOLOGY_TERMS': {},
#   'QUALIFICATIONS': 'High confidence interactions had an EPIC Score >= 0.683',
#   'TAGS': '-',
#   'SOURCEDB': 'BIOGRID'},
#  '2682231': {'BIOGRID_INTERACTION_ID': 2682231,
#   'ENTREZ_GENE_A': '19185',
#   'ENTREZ_GENE_B': '17189',
#   'BIOGRID_ID_A': 202431,
#   'BIOGRID_ID_B': 201329,
#   'SYSTEMATIC_NAME_A': '-',
#   'SYSTEMATIC_NAME_B': '-',
#   'OFFICIAL_SYMBOL_A': 'Psmd4',
#   'OFFICIAL_SYMBOL_B': 'Mb',
#   'SYNONYMS_A': 'Af1|Mcb1|angiocidin',
#   'SYNONYMS_B': 'AI325109',
#   'EXPERIMENTAL_SYSTEM': 'Co-fractionation',
#   'EXPERIMENTAL_SYSTEM_TYPE': 'physical',
#   'PUBMED_AUTHOR': 'Pourhaghighi R (2020)',
#   'PUBMED_ID': 32325033,
#   'ORGANISM_A': 10090,
#   'ORGANISM_B': 10090,
#   'THROUGHPUT': 'High Throughput',
#   'QUANTITATION': '0.711',
#   'MODIFICATION': '-',
#   'ONTOLOGY_TERMS': {},
#   'QUALIFICATIONS': 'High confidence interactions had an EPIC Score >= 0.683',
#   'TAGS': '-',
#   'SOURCEDB': 'BIOGRID'},
#  '3032208': {'BIOGRID_INTERACTION_ID': 3032208,
#   'ENTREZ_GENE_A': '1325',
#   'ENTREZ_GENE_B': '4151',
#   'BIOGRID_ID_A': 107718,
#   'BIOGRID_ID_B': 110321,
#   'SYSTEMATIC_NAME_A': 'UNQ307/PRO350',
#   'SYSTEMATIC_NAME_B': 'RP4-569D19.7',
#   'OFFICIAL_SYMBOL_A': 'CORT',
#   'OFFICIAL_SYMBOL_B': 'MB',
#   'SYNONYMS_A': 'CST-14|CST-17|CST-29',
#   'SYNONYMS_B': 'PVALB|myoglobgin',
#   'EXPERIMENTAL_SYSTEM': 'Affinity Capture-MS',
#   'EXPERIMENTAL_SYSTEM_TYPE': 'physical',
#   'PUBMED_AUTHOR': 'Huttlin EL (2021)',
#   'PUBMED_ID': 33961781,
#   'ORGANISM_A': 9606,
#   'ORGANISM_B': 9606,
#   'THROUGHPUT': 'High Throughput',
#   'QUANTITATION': '0.981415242',
#   'MODIFICATION': '-',
#   'ONTOLOGY_TERMS': {},
#   'QUALIFICATIONS': 'BioPlex 3.0 HEK 293T cells CompPASS score = 0.981415242, threshold = 0.75. Quantitative scores are calculated by CompPASS-Plus (Huttlin et al. Cell 2015, PMID: 26186194). The 0.75 threshold represents the top 2% of scores in HEK293T.|This data may be re-scored from BioPlex 1.0 (PMID: 26186194) and BioPlex 2.0 (PMID: 28514442). Only scores from within the same cell line in BioPlex 3.0 (PMID: 33961781) should be compared directly. For comparison of HEK293T and HCT116 interaction networks with relaxed threshold = 0.1, see BioPlex Interactome (https://bioplex.hms.harvard.edu/index.php).',
#   'TAGS': '-',
#   'SOURCEDB': 'BIOGRID'},
#  '3042608': {'BIOGRID_INTERACTION_ID': 3042608,
#   'ENTREZ_GENE_A': '54059',
#   'ENTREZ_GENE_B': '4151',
#   'BIOGRID_ID_A': 119869,
#   'BIOGRID_ID_B': 110321,
#   'SYSTEMATIC_NAME_A': '-',
#   'SYSTEMATIC_NAME_B': 'RP4-569D19.7',
#   'OFFICIAL_SYMBOL_A': 'YBEY',
#   'OFFICIAL_SYMBOL_B': 'MB',
#   'SYNONYMS_A': 'C21orf57',
#   'SYNONYMS_B': 'PVALB|myoglobgin',
#   'EXPERIMENTAL_SYSTEM': 'Affinity Capture-MS',
#   'EXPERIMENTAL_SYSTEM_TYPE': 'physical',
#   'PUBMED_AUTHOR': 'Huttlin EL (2021)',
#   'PUBMED_ID': 33961781,
#   'ORGANISM_A': 9606,
#   'ORGANISM_B': 9606,
#   'THROUGHPUT': 'High Throughput',
#   'QUANTITATION': '0.78944622',
#   'MODIFICATION': '-',
#   'ONTOLOGY_TERMS': {},
#   'QUALIFICATIONS': 'BioPlex 3.0 HEK 293T cells CompPASS score = 0.78944622, threshold = 0.75. Quantitative scores are calculated by CompPASS-Plus (Huttlin et al. Cell 2015, PMID: 26186194). The 0.75 threshold represents the top 2% of scores in HEK293T.|This data may be re-scored from BioPlex 1.0 (PMID: 26186194) and BioPlex 2.0 (PMID: 28514442). Only scores from within the same cell line in BioPlex 3.0 (PMID: 33961781) should be compared directly. For comparison of HEK293T and HCT116 interaction networks with relaxed threshold = 0.1, see BioPlex Interactome (https://bioplex.hms.harvard.edu/index.php).',
#   'TAGS': '-',
#   'SOURCEDB': 'BIOGRID'},
#  '3052403': {'BIOGRID_INTERACTION_ID': 3052403,
#   'ENTREZ_GENE_A': '84441',
#   'ENTREZ_GENE_B': '4151',
#   'BIOGRID_ID_A': 124080,
#   'BIOGRID_ID_B': 110321,
#   'SYSTEMATIC_NAME_A': '-',
#   'SYSTEMATIC_NAME_B': 'RP4-569D19.7',
#   'OFFICIAL_SYMBOL_A': 'MAML2',
#   'OFFICIAL_SYMBOL_B': 'MB',
#   'SYNONYMS_A': 'MAM-3|MAM2|MAM3|MLL-MAML2',
#   'SYNONYMS_B': 'PVALB|myoglobgin',
#   'EXPERIMENTAL_SYSTEM': 'Affinity Capture-MS',
#   'EXPERIMENTAL_SYSTEM_TYPE': 'physical',
#   'PUBMED_AUTHOR': 'Huttlin EL (2021)',
#   'PUBMED_ID': 33961781,
#   'ORGANISM_A': 9606,
#   'ORGANISM_B': 9606,
#   'THROUGHPUT': 'High Throughput',
#   'QUANTITATION': '0.78944622',
#   'MODIFICATION': '-',
#   'ONTOLOGY_TERMS': {},
#   'QUALIFICATIONS': 'BioPlex 3.0 HEK 293T cells CompPASS score = 0.78944622, threshold = 0.75. Quantitative scores are calculated by CompPASS-Plus (Huttlin et al. Cell 2015, PMID: 26186194). The 0.75 threshold represents the top 2% of scores in HEK293T.|This data may be re-scored from BioPlex 1.0 (PMID: 26186194) and BioPlex 2.0 (PMID: 28514442). Only scores from within the same cell line in BioPlex 3.0 (PMID: 33961781) should be compared directly. For comparison of HEK293T and HCT116 interaction networks with relaxed threshold = 0.1, see BioPlex Interactome (https://bioplex.hms.harvard.edu/index.php).',
#   'TAGS': '-',
#   'SOURCEDB': 'BIOGRID'},
#  '3131713': {'BIOGRID_INTERACTION_ID': 3131713,
#   'ENTREZ_GENE_A': '4151',
#   'ENTREZ_GENE_B': '286',
#   'BIOGRID_ID_A': 110321,
#   'BIOGRID_ID_B': 106783,
#   'SYSTEMATIC_NAME_A': 'RP4-569D19.7',
#   'SYSTEMATIC_NAME_B': '-',
#   'OFFICIAL_SYMBOL_A': 'MB',
#   'OFFICIAL_SYMBOL_B': 'ANK1',
#   'SYNONYMS_A': 'PVALB|myoglobgin',
#   'SYNONYMS_B': 'ANK|SPH1|SPH2',
#   'EXPERIMENTAL_SYSTEM': 'Affinity Capture-MS',
#   'EXPERIMENTAL_SYSTEM_TYPE': 'physical',
#   'PUBMED_AUTHOR': 'Huttlin EL (2021)',
#   'PUBMED_ID': 33961781,
#   'ORGANISM_A': 9606,
#   'ORGANISM_B': 9606,
#   'THROUGHPUT': 'High Throughput',
#   'QUANTITATION': '0.999583579',
#   'MODIFICATION': '-',
#   'ONTOLOGY_TERMS': {},
#   'QUALIFICATIONS': 'BioPlex 3.0 HEK 293T cells CompPASS score = 0.999583579, threshold = 0.75. Quantitative scores are calculated by CompPASS-Plus (Huttlin et al. Cell 2015, PMID: 26186194). The 0.75 threshold represents the top 2% of scores in HEK293T.|This data may be re-scored from BioPlex 1.0 (PMID: 26186194) and BioPlex 2.0 (PMID: 28514442). Only scores from within the same cell line in BioPlex 3.0 (PMID: 33961781) should be compared directly. For comparison of HEK293T and HCT116 interaction networks with relaxed threshold = 0.1, see BioPlex Interactome (https://bioplex.hms.harvard.edu/index.php).',
#   'TAGS': '-',
#   'SOURCEDB': 'BIOGRID'},
#  '3167982': {'BIOGRID_INTERACTION_ID': 3167982,
#   'ENTREZ_GENE_A': '5997',
#   'ENTREZ_GENE_B': '4151',
#   'BIOGRID_ID_A': 111929,
#   'BIOGRID_ID_B': 110321,
#   'SYSTEMATIC_NAME_A': 'GIG31',
#   'SYSTEMATIC_NAME_B': 'RP4-569D19.7',
#   'OFFICIAL_SYMBOL_A': 'RGS2',
#   'OFFICIAL_SYMBOL_B': 'MB',
#   'SYNONYMS_A': 'G0S8',
#   'SYNONYMS_B': 'PVALB|myoglobgin',
#   'EXPERIMENTAL_SYSTEM': 'Affinity Capture-MS',
#   'EXPERIMENTAL_SYSTEM_TYPE': 'physical',
#   'PUBMED_AUTHOR': 'Huttlin EL (2021)',
#   'PUBMED_ID': 33961781,
#   'ORGANISM_A': 9606,
#   'ORGANISM_B': 9606,
#   'THROUGHPUT': 'High Throughput',
#   'QUANTITATION': '0.985662305',
#   'MODIFICATION': '-',
#   'ONTOLOGY_TERMS': {},
#   'QUALIFICATIONS': 'BioPlex HCT HCT116 cells CompPASS score = 0.985662305, threshold = 0.75. Quantitative scores are calculated by CompPASS-Plus (Huttlin et al. Cell 2015, PMID: 26186194). The 0.75 threshold represents the top 2% of scores in HCT116.|Only scores from within the same cell line in BioPlex HCT (PMID: 33961781) should be compared directly. For comparison of HEK293T and HCT116 interaction networks with relaxed threshold = 0.1, see BioPlex Interactome (https://bioplex.hms.harvard.edu/index.php).',
#   'TAGS': '-',
#   'SOURCEDB': 'BIOGRID'},
#  '3434642': {'BIOGRID_INTERACTION_ID': 3434642,
#   'ENTREZ_GENE_A': '2806',
#   'ENTREZ_GENE_B': '4151',
#   'BIOGRID_ID_A': 109068,
#   'BIOGRID_ID_B': 110321,
#   'SYSTEMATIC_NAME_A': '-',
#   'SYSTEMATIC_NAME_B': 'RP4-569D19.7',
#   'OFFICIAL_SYMBOL_A': 'GOT2',
#   'OFFICIAL_SYMBOL_B': 'MB',
#   'SYNONYMS_A': 'KAT4|KATIV|mitAAT',
#   'SYNONYMS_B': 'PVALB|myoglobgin',
#   'EXPERIMENTAL_SYSTEM': 'Co-fractionation',
#   'EXPERIMENTAL_SYSTEM_TYPE': 'physical',
#   'PUBMED_AUTHOR': 'Havugimana PC (2022)',
#   'PUBMED_ID': 35831314,
#   'ORGANISM_A': 9606,
#   'ORGANISM_B': 9606,
#   'THROUGHPUT': 'High Throughput',
#   'QUANTITATION': '-',
#   'MODIFICATION': '-',
#   'ONTOLOGY_TERMS': {},
#   'QUALIFICATIONS': 'High confidence interactions were identified as having an EPIC score >=0.625 in applicable cell lines (MCF7, MDA231 or MCF10A)|MCF7 cell line (score 0.758)',
#   'TAGS': '-',
#   'SOURCEDB': 'BIOGRID'},
#  '3434701': {'BIOGRID_INTERACTION_ID': 3434701,
#   'ENTREZ_GENE_A': '4151',
#   'ENTREZ_GENE_B': '1728',
#   'BIOGRID_ID_A': 110321,
#   'BIOGRID_ID_B': 108072,
#   'SYSTEMATIC_NAME_A': 'RP4-569D19.7',
#   'SYSTEMATIC_NAME_B': '-',
#   'OFFICIAL_SYMBOL_A': 'MB',
#   'OFFICIAL_SYMBOL_B': 'NQO1',
#   'SYNONYMS_A': 'PVALB|myoglobgin',
#   'SYNONYMS_B': 'DHQU|DIA4|DTD|NMOR1|NMORI|QR1',
#   'EXPERIMENTAL_SYSTEM': 'Co-fractionation',
#   'EXPERIMENTAL_SYSTEM_TYPE': 'physical',
#   'PUBMED_AUTHOR': 'Havugimana PC (2022)',
#   'PUBMED_ID': 35831314,
#   'ORGANISM_A': 9606,
#   'ORGANISM_B': 9606,
#   'THROUGHPUT': 'High Throughput',
#   'QUANTITATION': '-',
#   'MODIFICATION': '-',
#   'ONTOLOGY_TERMS': {},
#   'QUALIFICATIONS': 'High confidence interactions were identified as having an EPIC score >=0.625 in applicable cell lines (MCF7, MDA231 or MCF10A)|MCF7 cell line (score 0.655)',
#   'TAGS': '-',
#   'SOURCEDB': 'BIOGRID'},
#  '3434702': {'BIOGRID_INTERACTION_ID': 3434702,
#   'ENTREZ_GENE_A': '4151',
#   'ENTREZ_GENE_B': '5037',
#   'BIOGRID_ID_A': 110321,
#   'BIOGRID_ID_B': 111076,
#   'SYSTEMATIC_NAME_A': 'RP4-569D19.7',
#   'SYSTEMATIC_NAME_B': '-',
#   'OFFICIAL_SYMBOL_A': 'MB',
#   'OFFICIAL_SYMBOL_B': 'PEBP1',
#   'SYNONYMS_A': 'PVALB|myoglobgin',
#   'SYNONYMS_B': 'HCNP|HCNPpp|HEL-210|HEL-S-34|PBP|PEBP|PEBP-1|RKIP',
#   'EXPERIMENTAL_SYSTEM': 'Co-fractionation',
#   'EXPERIMENTAL_SYSTEM_TYPE': 'physical',
#   'PUBMED_AUTHOR': 'Havugimana PC (2022)',
#   'PUBMED_ID': 35831314,
#   'ORGANISM_A': 9606,
#   'ORGANISM_B': 9606,
#   'THROUGHPUT': 'High Throughput',
#   'QUANTITATION': '-',
#   'MODIFICATION': '-',
#   'ONTOLOGY_TERMS': {},
#   'QUALIFICATIONS': 'High confidence interactions were identified as having an EPIC score >=0.625 in applicable cell lines (MCF7, MDA231 or MCF10A)|MCF7 cell line (score 0.693)',
#   'TAGS': '-',
#   'SOURCEDB': 'BIOGRID'},
#  '3434703': {'BIOGRID_INTERACTION_ID': 3434703,
#   'ENTREZ_GENE_A': '4151',
#   'ENTREZ_GENE_B': '127018',
#   'BIOGRID_ID_A': 110321,
#   'BIOGRID_ID_B': 126031,
#   'SYSTEMATIC_NAME_A': 'RP4-569D19.7',
#   'SYSTEMATIC_NAME_B': '-',
#   'OFFICIAL_SYMBOL_A': 'MB',
#   'OFFICIAL_SYMBOL_B': 'LYPLAL1',
#   'SYNONYMS_A': 'PVALB|myoglobgin',
#   'SYNONYMS_B': 'Q96AV0',
#   'EXPERIMENTAL_SYSTEM': 'Co-fractionation',
#   'EXPERIMENTAL_SYSTEM_TYPE': 'physical',
#   'PUBMED_AUTHOR': 'Havugimana PC (2022)',
#   'PUBMED_ID': 35831314,
#   'ORGANISM_A': 9606,
#   'ORGANISM_B': 9606,
#   'THROUGHPUT': 'High Throughput',
#   'QUANTITATION': '-',
#   'MODIFICATION': '-',
#   'ONTOLOGY_TERMS': {},
#   'QUALIFICATIONS': 'High confidence interactions were identified as having an EPIC score >=0.625 in applicable cell lines (MCF7, MDA231 or MCF10A)|MCF10A cell line (score 0.641)',
#   'TAGS': '-',
#   'SOURCEDB': 'BIOGRID'},
#  '3587977': {'BIOGRID_INTERACTION_ID': 3587977,
#   'ENTREZ_GENE_A': '388591',
#   'ENTREZ_GENE_B': '59108',
#   'BIOGRID_ID_A': 132764,
#   'BIOGRID_ID_B': 248730,
#   'SYSTEMATIC_NAME_A': '-',
#   'SYSTEMATIC_NAME_B': '-',
#   'OFFICIAL_SYMBOL_A': 'RNF207',
#   'OFFICIAL_SYMBOL_B': 'Mb',
#   'SYNONYMS_A': 'C1orf188',
#   'SYNONYMS_B': '-',
#   'EXPERIMENTAL_SYSTEM': 'Affinity Capture-MS',
#   'EXPERIMENTAL_SYSTEM_TYPE': 'physical',
#   'PUBMED_AUTHOR': 'Yuan L (2023)',
#   'PUBMED_ID': 35352799,
#   'ORGANISM_A': 9606,
#   'ORGANISM_B': 10116,
#   'THROUGHPUT': 'High Throughput',
#   'QUANTITATION': '-',
#   'MODIFICATION': '-',
#   'ONTOLOGY_TERMS': {},
#   'QUALIFICATIONS': '-',
#   'TAGS': '-',
#   'SOURCEDB': 'BIOGRID'},
#  '3721554': {'BIOGRID_INTERACTION_ID': 3721554,
#   'ENTREZ_GENE_A': '4151',
#   'ENTREZ_GENE_B': '23250',
#   'BIOGRID_ID_A': 110321,
#   'BIOGRID_ID_B': 116854,
#   'SYSTEMATIC_NAME_A': 'RP4-569D19.7',
#   'SYSTEMATIC_NAME_B': 'RP11-120K24.1',
#   'OFFICIAL_SYMBOL_A': 'MB',
#   'OFFICIAL_SYMBOL_B': 'ATP11A',
#   'SYNONYMS_A': 'PVALB|myoglobgin',
#   'SYNONYMS_B': 'ATPIH|ATPIS',
#   'EXPERIMENTAL_SYSTEM': 'Cross-Linking-MS (XL-MS)',
#   'EXPERIMENTAL_SYSTEM_TYPE': 'physical',
#   'PUBMED_AUTHOR': 'Gao H (2022)',
#   'PUBMED_ID': 35575683,
#   'ORGANISM_A': 9606,
#   'ORGANISM_B': 9606,
#   'THROUGHPUT': 'High Throughput',
#   'QUANTITATION': '-',
#   'MODIFICATION': '-',
#   'ONTOLOGY_TERMS': {},
#   'QUALIFICATIONS': 'High confidence crosslinked peptides were identified with the FDR set to 0.01 at the peptide-spectrum matches (PSM) level and PSMs >= 2.|MS non-cleavable crosslinker of bis(succinimidyl) with propargyl tag (BSP)',
#   'TAGS': '-',
#   'SOURCEDB': 'BIOGRID'},
#  '3745297': {'BIOGRID_INTERACTION_ID': 3745297,
#   'ENTREZ_GENE_A': '4151',
#   'ENTREZ_GENE_B': '55605',
#   'BIOGRID_ID_A': 110321,
#   'BIOGRID_ID_B': 120746,
#   'SYSTEMATIC_NAME_A': 'RP4-569D19.7',
#   'SYSTEMATIC_NAME_B': '-',
#   'OFFICIAL_SYMBOL_A': 'MB',
#   'OFFICIAL_SYMBOL_B': 'KIF21A',
#   'SYNONYMS_A': 'PVALB|myoglobgin',
#   'SYNONYMS_B': 'CFEOM1|FEOM1|FEOM3A',
#   'EXPERIMENTAL_SYSTEM': 'Cross-Linking-MS (XL-MS)',
#   'EXPERIMENTAL_SYSTEM_TYPE': 'physical',
#   'PUBMED_AUTHOR': 'Jiao F (2024)',
#   'PUBMED_ID': 38334954,
#   'ORGANISM_A': 9606,
#   'ORGANISM_B': 9606,
#   'THROUGHPUT': 'High Throughput',
#   'QUANTITATION': '-',
#   'MODIFICATION': '-',
#   'ONTOLOGY_TERMS': {},
#   'QUALIFICATIONS': 'Basal subtype|DSBSO-based XL-MS to identify protein interactions in  breast cancer patient-derived xenograft (PDX) model.|High confidence protein interactions had an FDR of 1.8%.',
#   'TAGS': '-',
#   'SOURCEDB': 'BIOGRID'},
#  '3745298': {'BIOGRID_INTERACTION_ID': 3745298,
#   'ENTREZ_GENE_A': '4151',
#   'ENTREZ_GENE_B': '51244',
#   'BIOGRID_ID_A': 110321,
#   'BIOGRID_ID_B': 119402,
#   'SYSTEMATIC_NAME_A': 'RP4-569D19.7',
#   'SYSTEMATIC_NAME_B': '-',
#   'OFFICIAL_SYMBOL_A': 'MB',
#   'OFFICIAL_SYMBOL_B': 'CCDC174',
#   'SYNONYMS_A': 'PVALB|myoglobgin',
#   'SYNONYMS_B': 'C3orf19',
#   'EXPERIMENTAL_SYSTEM': 'Cross-Linking-MS (XL-MS)',
#   'EXPERIMENTAL_SYSTEM_TYPE': 'physical',
#   'PUBMED_AUTHOR': 'Jiao F (2024)',
#   'PUBMED_ID': 38334954,
#   'ORGANISM_A': 9606,
#   'ORGANISM_B': 9606,
#   'THROUGHPUT': 'High Throughput',
#   'QUANTITATION': '-',
#   'MODIFICATION': '-',
#   'ONTOLOGY_TERMS': {},
#   'QUALIFICATIONS': 'Basal subtype|DSBSO-based XL-MS to identify protein interactions in  breast cancer patient-derived xenograft (PDX) model.|High confidence protein interactions had an FDR of 1.8%.',
#   'TAGS': '-',
#   'SOURCEDB': 'BIOGRID'}}

# %% [markdown]
# Then, use the `DataFrame.from_dict()` function to transform the data into a `pandas` dataframe. Please be noted that you can also export the dataframe into external files.

# %%
network_df = pd.DataFrame.from_dict(network, orient='index')
network_df.head() # print the first five row of data in dataframe
# Out:
#          BIOGRID_INTERACTION_ID ENTREZ_GENE_A ENTREZ_GENE_B  BIOGRID_ID_A  \
# 504736                   504736          5710          4151        111683
# 738356                   738356          4151           351        110321
# 1279762                 1279762          3316          4151        109548
# 2237373                 2237373          4151           286        110321
# 2259172                 2259172          1325          4151        107718
#
#          BIOGRID_ID_B SYSTEMATIC_NAME_A SYSTEMATIC_NAME_B OFFICIAL_SYMBOL_A  \
# 504736         110321      RP11-126K1.1      RP4-569D19.7             PSMD4
# 738356         106848      RP4-569D19.7                 -                MB
# 1279762        110321                 -      RP4-569D19.7             HSPB2
# 2237373        106783      RP4-569D19.7                 -                MB
# 2259172        110321     UNQ307/PRO350      RP4-569D19.7              CORT
#
#         OFFICIAL_SYMBOL_B                         SYNONYMS_A  ... PUBMED_ID  \
# 504736                 MB  AF|AF-1|ASF|MCB1|Rpn10|S5A|pUB-R5  ...  12601813
# 738356                APP                   PVALB|myoglobgin  ...  21832049
# 1279762                MB      HSP27|Hs.78846|LOH11CR1K|MKBP  ...  26465331
# 2237373              ANK1                   PVALB|myoglobgin  ...  28514442
# 2259172                MB               CST-14|CST-17|CST-29  ...  28514442
#
#         ORGANISM_A ORGANISM_B       THROUGHPUT  QUANTITATION  MODIFICATION  \
# 504736        9606       9606   Low Throughput             -             -
# 738356        9606       9606  High Throughput             -             -
# 1279762       9606       9606  High Throughput             -             -
# 2237373       9606       9606  High Throughput   0.995671066             -
# 2259172       9606       9606  High Throughput   0.897240724             -
#
#          ONTOLOGY_TERMS                                     QUALIFICATIONS  \
# 504736               {}                                                  -
# 738356               {}                                                  -
# 1279762              {}                                                  -
# 2237373              {}  BioPlex 2.0 HEK 293T cells CompPASS score = 0....
# 2259172              {}  BioPlex 2.0 HEK 293T cells CompPASS score = 0....
#
#         TAGS SOURCEDB
# 504736     -  BIOGRID
# 738356     -  BIOGRID
# 1279762    -  BIOGRID
# 2237373    -  BIOGRID
# 2259172    -  BIOGRID
#
# [5 rows x 24 columns]

# %%
network_df.shape
# Out:
# (24, 24)

# %%
network_df.OFFICIAL_SYMBOL_A = [gene.upper() for gene in network_df.OFFICIAL_SYMBOL_A]
network_df.OFFICIAL_SYMBOL_B = [gene.upper() for gene in network_df.OFFICIAL_SYMBOL_B]

# %%
network_df
# Out:
#          BIOGRID_INTERACTION_ID ENTREZ_GENE_A ENTREZ_GENE_B  BIOGRID_ID_A  \
# 504736                   504736          5710          4151        111683
# 738356                   738356          4151           351        110321
# 1279762                 1279762          3316          4151        109548
# 2237373                 2237373          4151           286        110321
# 2259172                 2259172          1325          4151        107718
# 2394069                 2394069        117287         59108        250731
# 2492369                 2492369          1107          4151        107532
# 2493156                 2493156          1108          4151        107533
# 2512085                 2512085        290364         59108        253181
# 2667790                 2667790         17189         12715        201329
# 2682231                 2682231         19185         17189        202431
# 3032208                 3032208          1325          4151        107718
# 3042608                 3042608         54059          4151        119869
# 3052403                 3052403         84441          4151        124080
# 3131713                 3131713          4151           286        110321
# 3167982                 3167982          5997          4151        111929
# 3434642                 3434642          2806          4151        109068
# 3434701                 3434701          4151          1728        110321
# 3434702                 3434702          4151          5037        110321
# 3434703                 3434703          4151        127018        110321
# 3587977                 3587977        388591         59108        132764
# 3721554                 3721554          4151         23250        110321
# 3745297                 3745297          4151         55605        110321
# 3745298                 3745298          4151         51244        110321
#
#          BIOGRID_ID_B SYSTEMATIC_NAME_A SYSTEMATIC_NAME_B OFFICIAL_SYMBOL_A  \
# 504736         110321      RP11-126K1.1      RP4-569D19.7             PSMD4
# 738356         106848      RP4-569D19.7                 -                MB
# 1279762        110321                 -      RP4-569D19.7             HSPB2
# 2237373        106783      RP4-569D19.7                 -                MB
# 2259172        110321     UNQ307/PRO350      RP4-569D19.7              CORT
# 2394069        248730                 -                 -             PARK7
# 2492369        110321                 -      RP4-569D19.7              CHD3
# 2493156        110321                 -      RP4-569D19.7              CHD4
# 2512085        248730                 -                 -             ITM2B
# 2667790        198726                 -                 -                MB
# 2682231        201329                 -                 -             PSMD4
# 3032208        110321     UNQ307/PRO350      RP4-569D19.7              CORT
# 3042608        110321                 -      RP4-569D19.7              YBEY
# 3052403        110321                 -      RP4-569D19.7             MAML2
# 3131713        106783      RP4-569D19.7                 -                MB
# 3167982        110321             GIG31      RP4-569D19.7              RGS2
# 3434642        110321                 -      RP4-569D19.7              GOT2
# 3434701        108072      RP4-569D19.7                 -                MB
# 3434702        111076      RP4-569D19.7                 -                MB
# 3434703        126031      RP4-569D19.7                 -                MB
# 3587977        248730                 -                 -            RNF207
# 3721554        116854      RP4-569D19.7     RP11-120K24.1                MB
# 3745297        120746      RP4-569D19.7                 -                MB
# 3745298        119402      RP4-569D19.7                 -                MB
#
#         OFFICIAL_SYMBOL_B                         SYNONYMS_A  ... PUBMED_ID  \
# 504736                 MB  AF|AF-1|ASF|MCB1|Rpn10|S5A|pUB-R5  ...  12601813
# 738356                APP                   PVALB|myoglobgin  ...  21832049
# 1279762                MB      HSP27|Hs.78846|LOH11CR1K|MKBP  ...  26465331
# 2237373              ANK1                   PVALB|myoglobgin  ...  28514442
# 2259172                MB               CST-14|CST-17|CST-29  ...  28514442
# 2394069                MB                 CAP1|DJ-1|Dj1|SP22  ...  26945066
# 2492369                MB                Mi-2a|Mi2-ALPHA|ZFH  ...  28977666
# 2493156                MB               CHD-4|Mi-2b|Mi2-BETA  ...  28977666
# 2512085                MB                         Bri|imBRI2  ...  29476059
# 2667790               CKM                           AI325109  ...  32325033
# 2682231                MB                Af1|Mcb1|angiocidin  ...  32325033
# 3032208                MB               CST-14|CST-17|CST-29  ...  33961781
# 3042608                MB                           C21orf57  ...  33961781
# 3052403                MB          MAM-3|MAM2|MAM3|MLL-MAML2  ...  33961781
# 3131713              ANK1                   PVALB|myoglobgin  ...  33961781
# 3167982                MB                               G0S8  ...  33961781
# 3434642                MB                  KAT4|KATIV|mitAAT  ...  35831314
# 3434701              NQO1                   PVALB|myoglobgin  ...  35831314
# 3434702             PEBP1                   PVALB|myoglobgin  ...  35831314
# 3434703           LYPLAL1                   PVALB|myoglobgin  ...  35831314
# 3587977                MB                           C1orf188  ...  35352799
# 3721554            ATP11A                   PVALB|myoglobgin  ...  35575683
# 3745297            KIF21A                   PVALB|myoglobgin  ...  38334954
# 3745298           CCDC174                   PVALB|myoglobgin  ...  38334954
#
#         ORGANISM_A ORGANISM_B       THROUGHPUT  QUANTITATION  MODIFICATION  \
# 504736        9606       9606   Low Throughput             -             -
# 738356        9606       9606  High Throughput             -             -
# 1279762       9606       9606  High Throughput             -             -
# 2237373       9606       9606  High Throughput   0.995671066             -
# 2259172       9606       9606  High Throughput   0.897240724             -
# 2394069      10116      10116   Low Throughput             -             -
# 2492369       9606       9606  High Throughput             -             -
# 2493156       9606       9606  High Throughput             -             -
# 2512085      10116      10116  High Throughput             -             -
# 2667790      10090      10090  High Throughput        0.8175             -
# 2682231      10090      10090  High Throughput         0.711             -
# 3032208       9606       9606  High Throughput   0.981415242             -
# 3042608       9606       9606  High Throughput    0.78944622             -
# 3052403       9606       9606  High Throughput    0.78944622             -
# 3131713       9606       9606  High Throughput   0.999583579             -
# 3167982       9606       9606  High Throughput   0.985662305             -
# 3434642       9606       9606  High Throughput             -             -
# 3434701       9606       9606  High Throughput             -             -
# 3434702       9606       9606  High Throughput             -             -
# 3434703       9606       9606  High Throughput             -             -
# 3587977       9606      10116  High Throughput             -             -
# 3721554       9606       9606  High Throughput             -             -
# 3745297       9606       9606  High Throughput             -             -
# 3745298       9606       9606  High Throughput             -             -
#
#          ONTOLOGY_TERMS                                     QUALIFICATIONS  \
# 504736               {}                                                  -
# 738356               {}                                                  -
# 1279762              {}                                                  -
# 2237373              {}  BioPlex 2.0 HEK 293T cells CompPASS score = 0....
# 2259172              {}  BioPlex 2.0 HEK 293T cells CompPASS score = 0....
# 2394069              {}                                                  -
# 2492369              {}                                                  -
# 2493156              {}                                                  -
# 2512085              {}                                                  -
# 2667790              {}  High confidence interactions had an EPIC Score...
# 2682231              {}  High confidence interactions had an EPIC Score...
# 3032208              {}  BioPlex 3.0 HEK 293T cells CompPASS score = 0....
# 3042608              {}  BioPlex 3.0 HEK 293T cells CompPASS score = 0....
# 3052403              {}  BioPlex 3.0 HEK 293T cells CompPASS score = 0....
# 3131713              {}  BioPlex 3.0 HEK 293T cells CompPASS score = 0....
# 3167982              {}  BioPlex HCT HCT116 cells CompPASS score = 0.98...
# 3434642              {}  High confidence interactions were identified a...
# 3434701              {}  High confidence interactions were identified a...
# 3434702              {}  High confidence interactions were identified a...
# 3434703              {}  High confidence interactions were identified a...
# 3587977              {}                                                  -
# 3721554              {}  High confidence crosslinked peptides were iden...
# 3745297              {}  Basal subtype|DSBSO-based XL-MS to identify pr...
# 3745298              {}  Basal subtype|DSBSO-based XL-MS to identify pr...
#
#         TAGS SOURCEDB
# 504736     -  BIOGRID
# 738356     -  BIOGRID
# 1279762    -  BIOGRID
# 2237373    -  BIOGRID
# 2259172    -  BIOGRID
# 2394069    -  BIOGRID
# 2492369    -  BIOGRID
# 2493156    -  BIOGRID
# 2512085    -  BIOGRID
# 2667790    -  BIOGRID
# 2682231    -  BIOGRID
# 3032208    -  BIOGRID
# 3042608    -  BIOGRID
# 3052403    -  BIOGRID
# 3131713    -  BIOGRID
# 3167982    -  BIOGRID
# 3434642    -  BIOGRID
# 3434701    -  BIOGRID
# 3434702    -  BIOGRID
# 3434703    -  BIOGRID
# 3587977    -  BIOGRID
# 3721554    -  BIOGRID
# 3745297    -  BIOGRID
# 3745298    -  BIOGRID
#
# [24 rows x 24 columns]

# %% [markdown]
# Please observe the dataframe above, these are the information available from the protein-protein interaction data returned from the webserver. Look at the available attributes, in this example, we focus only on the two columns, which are the `OFFICIAL_SYMBOL_A` and `OFFICIAL_SYMBOL_B`. This is the indication of there is interaction between these two proteins.

# %% [markdown]
# ### 2. Generate network graph for the protein-protein interaction
# From now onwards, we will use the dataframe in generating the network graph. In this case, we will use the `from_pandas_edgelist()` function from `networkx` and pass in the dataframe we generate in STEP 1, then pass in the two columns name as the following parameters.

# %%
network_graph = nx.from_pandas_edgelist(network_df, "OFFICIAL_SYMBOL_A", "OFFICIAL_SYMBOL_B")

# %% [markdown]
# Once the network graph structure is generated, we can access many of the properties about the network. For example, we can get information about the number of edges and number of nodes using `number_of_edges()` and `number_of_nodes()` respectively.

# %%
print('Number of edges:', network_graph.number_of_edges())
print('Number of nodes:', network_graph.number_of_nodes())
# Out:
# Number of edges: 21
# Number of nodes: 22

# %% [markdown]
# We also can get number of interactions available for each node using the `degree()` function of the network graph object.

# %%
network_graph.degree()
# Out:
# DegreeView({'PSMD4': 1, 'MB': 21, 'APP': 1, 'HSPB2': 1, 'ANK1': 1, 'CORT': 1, 'PARK7': 1, 'CHD3': 1, 'CHD4': 1, 'ITM2B': 1, 'CKM': 1, 'YBEY': 1, 'MAML2': 1, 'RGS2': 1, 'GOT2': 1, 'NQO1': 1, 'PEBP1': 1, 'LYPLAL1': 1, 'RNF207': 1, 'ATP11A': 1, 'KIF21A': 1, 'CCDC174': 1})

# %% [markdown]
# Then, we can also check on the centrality of the nodes, by checking the `degree_centrality()` function from `networkx` and pass in the network graph object. This will return the measured centrality of each node, closer to 1.0 tend to be the center. This is directly correlate with the output of `degree()` above.

# %%
degree_centrality = nx.degree_centrality(network_graph)

# %% [markdown]
# Nodes that closer to the center are the nodes that having higher number of interactions compare to the one further from the center. In this case, we also can filter certain number of proteins according to the centrality. In following example, we can extract the top five.

# %%
top_5_proteins = sorted(degree_centrality.items(), key=lambda x:-x[1])[:5]
top_5_proteins
# Out:
# [('MB', 1.0),
#  ('PSMD4', 0.047619047619047616),
#  ('APP', 0.047619047619047616),
#  ('HSPB2', 0.047619047619047616),
#  ('ANK1', 0.047619047619047616)]

# %% [markdown]
# ### 3. Visualizing the network graph
# Next, we can further visualize the network using `spring_layout()` function from `networkx` and pass in the network graph object. This will generate a layout based on the network graph object, which include the coordinates of each node. This is a random process, which by default it will generate different layout everytime. Unless set the `seed` parameter within `spring_layout` to a specific number, then it will always generate same layout.

# %%
slayout = nx.spring_layout(network_graph, seed=123)

# %% [markdown]
# Then, to generate the graph view, use the `draw()` function from `networkx`, pass in the network graph object and the layout from above. There are different settings available for the graph display, such as:
# - `with_labels`: set True to display text on each node.
# - `node_size`: the size of the node whether big or small.
# - `node_color`: setting the color of the node.
# - `edge_colr`: setting the color of the edge.
# - `font_size`: setting the size of the font.
# - `nodelist`: define specific nodes to be visualized

# %%
nx.draw(network_graph, slayout, with_labels=False, node_size=20, node_color='lightblue', font_size=8)

# %% [markdown]
# We can overlay the images by executing two `draw()` functions at the same time, this can be useful if we want to overlay some additional information. For example, in this case, let's obtain the protein names from the top five proteins.

# %%
high_centrality_nodes = [node for node, centrality in top_5_proteins]
high_centrality_nodes
# Out:
# ['MB', 'PSMD4', 'APP', 'HSPB2', 'ANK1']

# %% [markdown]
# At first, we will use the `draw()` to draw the first layer of the network graph. <br>
# Then, we can call the `draw_networkx_nodes()` function to draw a second layer on top of the first one, at this line, we will set the `nodelist` parameter to the list of top five proteins above, and set it in different color.

# %%
nx.draw(network_graph, slayout, with_labels=False, node_size=20, node_color='lightblue')
nx.draw_networkx_nodes(network_graph, slayout, nodelist=high_centrality_nodes, node_size=20, node_color='orange')

# %% [markdown]
# However, in this case, please be noted that, visualization might not be a meaningful if we visualize the entire data. But please be aware that this is just visualization, the PPI data still can be useful for integration with other analysis.
